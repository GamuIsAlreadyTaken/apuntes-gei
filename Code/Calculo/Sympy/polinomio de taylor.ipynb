# %%
import sympy as sp

x = sp.Symbol('x', real=True)

f_ = 1/((1+x)**(1/4))
f = sp.Lambda(x, f_)

f_taylor_ = 1-(1/4)*x
f_taylor = sp.Lambda(x, f_taylor_)

sp.plot(f(x), f_taylor(x))
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
